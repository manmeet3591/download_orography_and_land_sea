# %%
# !wget https://www.ngdc.noaa.gov/thredds/fileServer/global/ETOPO2022/60s/60s_bed_elev_netcdf/ETOPO_2022_v1_60s_N90W180_bed.nc
# Out:
# --2025-05-05 19:45:16--  https://www.ngdc.noaa.gov/thredds/fileServer/global/ETOPO2022/60s/60s_bed_elev_netcdf/ETOPO_2022_v1_60s_N90W180_bed.nc
# Resolving www.ngdc.noaa.gov (www.ngdc.noaa.gov)... 140.172.190.2, 140.172.190.1
# Connecting to www.ngdc.noaa.gov (www.ngdc.noaa.gov)|140.172.190.2|:443... connected.
# HTTP request sent, awaiting response... 200 200
# Length: unspecified [application/x-netcdf]
# Saving to: ‘ETOPO_2022_v1_60s_N90W180_bed.nc.1’
#
# ETOPO_2022_v1_60s_N     [       <=>          ] 468.52M  18.1MB/s    in 26s
#
# 2025-05-05 19:45:42 (17.9 MB/s) - ‘ETOPO_2022_v1_60s_N90W180_bed.nc.1’ saved [491284376]

# %%
# !wget https://pmm.nasa.gov/sites/default/files/downloads/IMERG_land_sea_mask.nc.gz
# Out:
# --2025-05-05 19:45:42--  https://pmm.nasa.gov/sites/default/files/downloads/IMERG_land_sea_mask.nc.gz
# Resolving pmm.nasa.gov (pmm.nasa.gov)... 198.118.195.71, 2001:4d0:241a:40a0::47
# Connecting to pmm.nasa.gov (pmm.nasa.gov)|198.118.195.71|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://gpm.nasa.gov/sites/default/files/downloads/IMERG_land_sea_mask.nc.gz [following]
# --2025-05-05 19:45:42--  https://gpm.nasa.gov/sites/default/files/downloads/IMERG_land_sea_mask.nc.gz
# Resolving gpm.nasa.gov (gpm.nasa.gov)... 198.118.195.71, 2001:4d0:241a:40a0::47
# Connecting to gpm.nasa.gov (gpm.nasa.gov)|198.118.195.71|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4804303 (4.6M) [application/x-gzip]
# Saving to: ‘IMERG_land_sea_mask.nc.gz.1’
#
# IMERG_land_sea_mask 100%[===================>]   4.58M  17.3MB/s    in 0.3s
#
# ...

# %%
# !unzip IMERG_land_sea_mask.nc.gz
# Out:
# Archive:  IMERG_land_sea_mask.nc.gz
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of IMERG_land_sea_mask.nc.gz or
#         IMERG_land_sea_mask.nc.gz.zip, and cannot find IMERG_land_sea_mask.nc.gz.ZIP, period.

# %%
# !ls
# Out:
# ETOPO_2022_v1_60s_N90W180_bed.nc    IMERG_land_sea_mask.nc.gz	 sample_data
# ETOPO_2022_v1_60s_N90W180_bed.nc.1  IMERG_land_sea_mask.nc.gz.1

# %%
import xarray as xr

# %%
ds_topo = xr.open_dataset('ETOPO_2022_v1_60s_N90W180_bed.nc')
ds_topo
# Out:
# <xarray.Dataset> Size: 933MB
# Dimensions:  (lat: 10800, lon: 21600)
# Coordinates:
#   * lat      (lat) float64 86kB -89.99 -89.97 -89.96 ... 89.96 89.97 89.99
#   * lon      (lon) float64 173kB -180.0 -180.0 -180.0 ... 180.0 180.0 180.0
# Data variables:
#     crs      |S1 1B ...
#     z        (lat, lon) float32 933MB ...
# Attributes:
#     GDAL_AREA_OR_POINT:             Area
#     node_offset:                    1
#     GDAL_TIFFTAG_COPYRIGHT:         DOC/NOAA/NESDIS/NCEI > National Centers f...
#     GDAL_TIFFTAG_DATETIME:          20220929123913.0
#     GDAL_TIFFTAG_IMAGEDESCRIPTION:  Topography-Bathymetry; EGM2008 height
#     Conventions:                    CF-1.5
#     GDAL:                           GDAL 3.3.2, released 2021/09/01
#     NCO:                            netCDF Operators version 4.9.1 (Homepage ...
